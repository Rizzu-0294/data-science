# %% [markdown]
# <image src="uses.jpg" style="width:400; height:200px">NodeJs

# %% [markdown]
# # data manipulation using csv file

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import sklearn as sl

# %%
data =pd.read_csv("Salary_dataset.csv")
new_data = data.drop(columns=['Unnamed: 0'])
print(new_data)
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
x=new_data.iloc[:,:-1].values
y=new_data.iloc[:,1].values

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=2)
print(x_test)
# Out:
# [[9.6]
#  [6.1]]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.959431875862919

# %%
y_pred=lr.predict(x_test)
x_pred=lr.predict(x_train)
y_pred
x_pred
# Out:
# array([ 55718.37048699,  71656.87628477,  75407.11294307,  52905.69299327,
#        107284.12453861,  46342.77884124,  63218.84380359, 110096.80203234,
#        124160.18950096,  64156.40296817,  36029.62803092,  73531.99461392,
#         44467.66051209,  55718.37048699,  81032.46793052,  63218.84380359,
#         60406.16630987, 122285.07117181,  67906.63962647, 102596.32871574,
#         92283.17790542,  53843.25215784,  99783.65122202,  89470.50041169,
#        115722.15701979,  39779.86468922,  62281.28463902,  37904.74636007])

# %%
lr.score(x_test,y_test)
# Out:
# 0.44155969634102643

# %%
plt.scatter(x_train,y_train, color="m")
plt.plot(x_train,x_pred,color="g")
plt.title("salary vs exp")
plt.xlabel("year of exp")
plt.ylabel("salary")
plt.show()
