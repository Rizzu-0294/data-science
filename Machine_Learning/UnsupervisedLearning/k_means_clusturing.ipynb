# %% [markdown]
# # Unsupervised learning consist of nueral networks where nueral are nothing but nodes

# %% [markdown]
# # types of nueral networks
# ## Feedforward neural network (FNN)
# ## Convolutional Nueral network (CNN)
# ## Recurrent Nueral network (RNN)
# ## Long short term memory network (LSTMN)
# ## Generative adversarial network (GAN)

# %% [markdown]
# # algorithms in unsupervised learning
# ## k-means clusturing

# %%
import pandas as pd

# %%
df=pd.read_csv('farmer.csv')

# %%
df.head(10)
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice
# 5  69  37  42    23.058049  83.370118  7.073454  251.055000  rice
# 6  69  55  38    22.708838  82.639414  5.700806  271.324860  rice
# 7  94  53  40    20.277744  82.894086  5.718627  241.974195  rice
# 8  89  54  38    24.515881  83.535216  6.685346  230.446236  rice
# 9  68  58  38    23.223974  83.033227  6.336254  221.209196  rice

# %%
df['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %%
labels=df.groupby('label')

# %%
labels[['humidity']].mean()
# Out:
#               humidity
# label
# apple        92.333383
# banana       80.358123
# blackgram    65.118426
# chickpea     16.860439
# coconut      94.844272
# coffee       58.869846
# cotton       79.843474
# grapes       81.875228
# jute         79.639864
# kidneybeans  21.605357
# lentil       64.804785
# maize        65.092249
# mango        50.156573
# mothbeans    53.160418
# mungbean     85.499975
# muskmelon    92.342802
# orange       92.170209
# papaya       92.403388
# pigeonpeas   48.061633
# pomegranate  90.125504
# rice         82.272822
# watermelon   85.160375

# %%
label=list(labels[['N']].mean().index) 
# label
avg_nitrogen  = list(labels[['N']].mean().values.ravel()) # this ravel function convert the label into 1D array
# avg_nitrogen

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
plt.bar(x=label,height=avg_nitrogen,ec='k')
plt.xticks(rotation=90)
plt.show()

# %%
sb.catplot(x=label,y=avg_nitrogen,kind='bar')
plt.xticks(rotation=90)
plt.title("catplot between label and avg_nitrogen")
plt.show()

# %%
x=df.drop('label',axis=1)
x.head(10)
# Out:
#     N   P   K  temperature   humidity        ph    rainfall
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340
# 5  69  37  42    23.058049  83.370118  7.073454  251.055000
# 6  69  55  38    22.708838  82.639414  5.700806  271.324860
# 7  94  53  40    20.277744  82.894086  5.718627  241.974195
# 8  89  54  38    24.515881  83.535216  6.685346  230.446236
# 9  68  58  38    23.223974  83.033227  6.336254  221.209196

# %%
sb.boxplot(x['humidity'])
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.subplot(3,3,1)
sb.boxplot(df['N'])
plt.subplot(3,3,2)
sb.boxplot(df['P'])
plt.subplot(3,3,3)
sb.boxplot(df['K'])
plt.subplot(3,3,4)
sb.boxplot(df['humidity'])
plt.subplot(3,3,5)
sb.boxplot(df['temperature'])
plt.subplot(3,3,6)
sb.boxplot(df['ph'])
plt.subplot(3,3,7)
sb.boxplot(df['rainfall'])
plt.show()

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
# sb.distplot(x['temperature'])
# plt.title("Distplot")
sb.histplot(x['temperature'],kde="true")
plt.show()

# %%
sb.distplot(x['N'])
plt.title("Distplot")
# Out:
# Text(0.5, 1.0, 'Distplot')

# %%
sb.distplot(x['P'])
plt.title("Distplot")
# Out:
# Text(0.5, 1.0, 'Distplot')

# %%
sb.distplot(x['humidity'])
plt.title("Distplot")
# Out:
# Text(0.5, 1.0, 'Distplot')

# %%
from sklearn.preprocessing import StandardScaler  # this standardscaler standardize the model using normalization(0-1) it convert mean=0,standard deviation=1
 # we can also call it z score , z= x-m/sd and also use for outliers.
std=StandardScaler()

# %%
x_tranformed=std.fit_transform(x)

# %%
x_tranformed
# Out:
# array([[ 1.0687974 , -0.34455075, -0.1016875 , ...,  0.47266646,
#          0.04330173,  1.8103605 ],
#        [ 0.93332887,  0.14061552, -0.14118477, ...,  0.39705125,
#          0.73487256,  2.24205791],
#        [ 0.25598625,  0.04964684, -0.08193887, ...,  0.48695381,
#          1.77151047,  2.92106603],
#        ...,
#        [ 1.82742114, -0.61745677, -0.35841972, ..., -0.19123516,
#         -0.13812031,  1.27141766],
#        [ 1.80032743, -0.64777967, -0.27942519, ..., -0.86951801,
#          0.37390383,  0.43154519],
#        [ 1.44810927, -1.07230015, -0.35841972, ..., -0.49802006,
#          0.40109573,  0.68200518]])

# %%
sb.distplot(x_tranformed[:,0])
plt.show()

# %%
sb.distplot(x)
plt.show()

# %%
pd.DataFrame(x_tranformed).describe()[0][1]
# Out:
# -1.0335167065601457e-16

# %%
x['N'].max()
# Out:
# 140

# %%
desc=pd.DataFrame(x_tranformed).describe()
desc_formatted=desc.applymap(lambda x:f"{int(x):d}")
desc_formatted
# Out:
#           0     1     2     3     4     5     6
# count  2200  2200  2200  2200  2200  2200  2200
# mean      0     0     0     0     0     0     0
# std       1     1     1     1     1     1     1
# min      -1    -1     0    -3    -2    -3    -1
# 25%       0     0     0     0     0     0     0
# 50%       0     0     0     0     0     0     0
# 75%       0     0     0     0     0     0     0
# max       2     2     3     3     1     4     3

# %%
from sklearn.cluster import KMeans

# %%
kmeans=KMeans()

# %%
kmeans.fit(x_tranformed)
# Out:
# KMeans()

# %%
kmeans.fit_predict(x_tranformed)
# Out:
# array([7, 7, 7, ..., 7, 5, 7])

# %%
label=kmeans.labels_
label
# Out:
# array([7, 7, 7, ..., 7, 5, 7])

# %%
df['label_or_cluster_8']=label

# %%
df[df['label']=='rice']['label_or_cluster_8'].value_counts()
# Out:
# label_or_cluster_8
# 7    100
# Name: count, dtype: int64

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label  \
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
#       label_or_cluster_8
# 0                      7
# 1                      7
# ...

# %%
df[df['label_or_cluster_8']==7]['label'].value_counts()
# Out:
# label
# rice          100
# jute          100
# coffee         81
# papaya         21
# pigeonpeas      3
# Name: count, dtype: int64

# %%
df['label_or_cluster_8'].value_counts()
# Out:
# label_or_cluster_8
# 5    417
# 1    406
# 7    305
# 4    293
# 0    219
# 3    200
# 6    199
# 2    161
# Name: count, dtype: int64

# %% [markdown]
# # read about inertia, dunn index ,silhouttee score, $ manhattan $ $ distance $
